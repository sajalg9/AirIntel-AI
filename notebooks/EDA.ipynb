# %% [markdown]
# # AirSense AI EDA
#
# This notebook explores the combined AQI dataset across all five cities and checks the data quality before model training.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
if str(ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(ROOT / 'src'))

from preprocessing import load_all_city_data, clean_aqi_dataframe, prepare_dataframe

df = load_all_city_data()
df.head()

# %%
prepared = prepare_dataframe(df)
summary = prepared.groupby('City')[['AQI', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3']].agg(['mean', 'max', 'min'])
summary
