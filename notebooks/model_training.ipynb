# %% [markdown]
# # AirSense AI Model Training
#
# This notebook runs the shared training pipeline for the baseline, LSTM, and Transformer models.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
if str(ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(ROOT / 'src'))

from models.train import train_all_models

result = train_all_models(output_dir=ROOT / 'saved_models', lstm_epochs=5, transformer_epochs=5)
result['summary']

# %%
result['metrics']
